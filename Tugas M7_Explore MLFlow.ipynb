# %% [markdown]
# ## ML Flow

# %% [markdown]
# MLflow adalah platform open source yang digunakan untuk mengelola alur kerja Machine Learning (ML). MLflow membantu dalam mengatur, melacak dan
# mengelola eksperimen ML, dari pengembangan model hingga produksi.
#
# MLflow memiliki komponen untuk memonitor model ketika training dan running, kemampuan menyimpan model, me-load model di production code dan membuat
# pipeline.
# Core Component:
# 1. Tracking
# 2. Model registry
# 3. ML Flow Deployments for LLMs
# 4. Evaluate
# 5. Prompt Engineering UI
# 6. Recipes
# 7. Project
#
# Why use ML Flow?
# 1. Traceability
# 2. Consistency
# 3. Flexibelity
#
# Use Case of ML Flow:
# 1. Experiment tracking
# 2. Model Selection & Experiment
# 3. Model Performmance Monitoring
# 4. Collaborative Projects

# %%
import pandas as pd
import numpy as np
import os
from pycaret.classification import *
from pycaret.datasets import get_data
import ydata_profiling as pp
import mlflow
import mlflow.sklearn

# %% [markdown]
# Command Prompt
# C:\Users\USER>mlflow ui
# C:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\_internal\_config.py:322: UserWarning: Valid config keys have changed in V2:
#  'schema_extra' has been renamed to 'json_schema_extra'
#   warnings.warn(message, UserWarning)
# INFO:waitress:Serving on http://127.0.0.1:5000

# %%
# Set URI pelacakan MLflow
mlflow.set_tracking_uri('http://localhost:5000')

# Set eksperimen yang diinginkan
mlflow.set_experiment('model-heart_cleveland')

# Aktifkan autologging untuk semua model sklearn
mlflow.sklearn.autolog()
# Out:
# 2024/04/17 18:48:20 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.

# %% [markdown]
# Baris set URI menetapkan URI untuk pelacakan dan menunjukkan ke MLflow di mana catatan eksperimen harus disimpan. Dalam kasus ini, pelacakan dilakukan di http://localhost:5000, yang mungkin merupakan alamat lokal dari server MLflow yang berjalan.
#
# Langkah ini menetapkan eksperimen yang diinginkan. Eksperimen adalah kumpulan run atau percobaan yang memiliki tujuan atau fokus yang sama. Di sini, kita menetapkan eksperimen dengan nama 'model-heart_cleveland'.
#
# Baris ini mengaktifkan autologging untuk semua model sklearn. Autologging secara otomatis mencatat metrik, parameter, dan artefak model selama proses pelatihan, tanpa perlu menambahkan log manual. Autologging mempercepat proses pelacakan dan dokumentasi model. Dengan menggunakan autologging sklearn, semua model yang dilatih dalam kode akan otomatis dicatat oleh MLflow.

# %%
# Mulai MLflow run
with mlflow.start_run(run_name='iterasi_2'):

    # Import dataset
    dataset_path = 'D:/SDT Semester 4/Machine Learning Ops/heart_cleveland_upload.csv'
    dataset = pd.read_csv(dataset_path)

    # Catat lokasi dataset (Lokasi dataset dan nama file dataset dicatat sebagai parameter menggunakan mlflow.log_param())
    mlflow.log_param('dataset_path', dataset_path)

    # Catat nama file dataset
    dataset_filename = os.path.basename(dataset_path)
    print("Dataset Filename:", dataset_filename)  # Print the dataset filename
    mlflow.log_param('dataset_filename', dataset_filename)

    # Analisa dataset menggunakan profiler
    profile = pp.ProfileReport(dataset)
    profile.to_file("output_mlopsM7.html")

    # Bagi dataset menjadi data latih dan data uji
    data_train = dataset.sample(frac=0.8, random_state=110)
    data_unseen = dataset.drop(data_train.index)
    data_train.reset_index(drop=True, inplace=True)
    data_unseen.reset_index(drop=True, inplace=True)

    # Setup eksperimen
    cat_features = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'thal']
    experiment = setup(data_train, target='condition', categorical_features=cat_features)

    # Proses training model
    best_model = compare_models(sort='Precision', fold=10, round=2)

    # Simpan model ke dalam direktori tempat menyimpan model
    model_path = "sklearn-model"
    mlflow.sklearn.log_model(best_model, model_path)

    # Analisis model
    evaluate_model(best_model)
# Out:
# Dataset Filename: heart_cleveland_upload.csv
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# <style type="text/css">
# #T_4f74a_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4f74a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f74a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4f74a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f74a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f74a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4f74a_row0_col1" class="data row0 col1" >3431</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f74a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4f74a_row1_col1" class="data row1 col1" >condition</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4f74a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4f74a_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4f74a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4f74a_row3_col1" class="data row3 col1" >(238, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4f74a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4f74a_row4_col1" class="data row4 col1" >(238, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4f74a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4f74a_row5_col1" class="data row5 col1" >(166, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4f74a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4f74a_row6_col1" class="data row6 col1" >(72, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4f74a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4f74a_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4f74a_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_4f74a_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4f74a_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_4f74a_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4f74a_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_4f74a_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4f74a_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_4f74a_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4f74a_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_4f74a_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4f74a_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_4f74a_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4f74a_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_4f74a_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4f74a_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_4f74a_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4f74a_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_4f74a_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4f74a_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_4f74a_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4f74a_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_4f74a_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4f74a_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_4f74a_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4f74a_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_4f74a_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4f74a_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4f74a_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_4f74a_row21_col1" class="data row21 col1" >5434</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_03a43 th {
#   text-align: left;
# }
# #T_03a43_row0_col0, #T_03a43_row1_col0, #T_03a43_row1_col1, #T_03a43_row1_col3, #T_03a43_row1_col4, #T_03a43_row1_col5, #T_03a43_row1_col6, #T_03a43_row1_col7, #T_03a43_row2_col0, #T_03a43_row2_col1, #T_03a43_row2_col4, #T_03a43_row2_col5, #T_03a43_row2_col6, #T_03a43_row2_col7, #T_03a43_row3_col0, #T_03a43_row3_col1, #T_03a43_row3_col3, #T_03a43_row3_col4, #T_03a43_row3_col5, #T_03a43_row3_col6, #T_03a43_row3_col7, #T_03a43_row4_col0, #T_03a43_row4_col1, #T_03a43_row4_col3, #T_03a43_row4_col4, #T_03a43_row4_col5, #T_03a43_row4_col6, #T_03a43_row4_col7, #T_03a43_row5_col0, #T_03a43_row5_col1, #T_03a43_row5_col3, #T_03a43_row5_col4, #T_03a43_row5_col5, #T_03a43_row5_col6, #T_03a43_row5_col7, #T_03a43_row6_col0, #T_03a43_row6_col1, #T_03a43_row6_col3, #T_03a43_row6_col4, #T_03a43_row6_col5, #T_03a43_row6_col6, #T_03a43_row6_col7, #T_03a43_row7_col0, #T_03a43_row7_col1, #T_03a43_row7_col3, #T_03a43_row7_col4, #T_03a43_row7_col5, #T_03a43_row7_col6, #T_03a43_row7_col7, #T_03a43_row8_col0, #T_03a43_row8_col1, #T_03a43_row8_col3, #T_03a43_row8_col4, #T_03a43_row8_col5, #T_03a43_row8_col6, #T_03a43_row8_col7, #T_03a43_row9_col0, #T_03a43_row9_col1, #T_03a43_row9_col3, #T_03a43_row9_col4, #T_03a43_row9_col5, #T_03a43_row9_col6, #T_03a43_row9_col7, #T_03a43_row10_col0, #T_03a43_row10_col1, #T_03a43_row10_col3, #T_03a43_row10_col4, #T_03a43_row10_col5, #T_03a43_row10_col6, #T_03a43_row10_col7, #T_03a43_row11_col0, #T_03a43_row11_col1, #T_03a43_row11_col3, #T_03a43_row11_col4, #T_03a43_row11_col5, #T_03a43_row11_col6, #T_03a43_row11_col7, #T_03a43_row12_col0, #T_03a43_row12_col1, #T_03a43_row12_col3, #T_03a43_row12_col4, #T_03a43_row12_col5, #T_03a43_row12_col6, #T_03a43_row12_col7, #T_03a43_row13_col0, #T_03a43_row13_col1, #T_03a43_row13_col3, #T_03a43_row13_col4, #T_03a43_row13_col5, #T_03a43_row13_col6, #T_03a43_row13_col7, #T_03a43_row14_col0, #T_03a43_row14_col1, #T_03a43_row14_col3, #T_03a43_row14_col4, #T_03a43_row14_col5, #T_03a43_row14_col6, #T_03a43_row14_col7 {
#   text-align: left;
# }
# #T_03a43_row0_col1, #T_03a43_row0_col2, #T_03a43_row0_col3, #T_03a43_row0_col4, #T_03a43_row0_col5, #T_03a43_row0_col6, #T_03a43_row0_col7, #T_03a43_row1_col2, #T_03a43_row2_col2, #T_03a43_row2_col3, #T_03a43_row3_col2, #T_03a43_row4_col2, #T_03a43_row5_col2, #T_03a43_row6_col2, #T_03a43_row7_col2, #T_03a43_row8_col2, #T_03a43_row9_col2, #T_03a43_row10_col2, #T_03a43_row11_col2, #T_03a43_row12_col2, #T_03a43_row13_col2, #T_03a43_row14_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_03a43_row0_col8, #T_03a43_row1_col8, #T_03a43_row2_col8, #T_03a43_row4_col8, #T_03a43_row5_col8, #T_03a43_row6_col8, #T_03a43_row7_col8, #T_03a43_row8_col8, #T_03a43_row9_col8, #T_03a43_row10_col8, #T_03a43_row11_col8, #T_03a43_row12_col8, #T_03a43_row13_col8, #T_03a43_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_03a43_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_03a43">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03a43_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_03a43_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_03a43_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_03a43_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_03a43_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_03a43_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_03a43_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_03a43_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_03a43_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03a43_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_03a43_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_03a43_row0_col1" class="data row0 col1" >0.86</td>
#       <td id="T_03a43_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_03a43_row0_col3" class="data row0 col3" >0.80</td>
#       <td id="T_03a43_row0_col4" class="data row0 col4" >0.89</td>
#       <td id="T_03a43_row0_col5" class="data row0 col5" >0.83</td>
#       <td id="T_03a43_row0_col6" class="data row0 col6" >0.71</td>
#       <td id="T_03a43_row0_col7" class="data row0 col7" >0.73</td>
#       <td id="T_03a43_row0_col8" class="data row0 col8" >5.19</td>
#     </tr>
#     <tr>
#       <th id="T_03a43_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_03a43_row1_col0" class="data row1 col0" >CatBoost Classifier</td>
#       <td id="T_03a43_row1_col1" class="data row1 col1" >0.83</td>
#       <td id="T_03a43_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_03a43_row1_col3" class="data row1 col3" >0.78</td>
#       <td id="T_03a43_row1_col4" class="data row1 col4" >0.86</td>
#       <td id="T_03a43_row1_col5" class="data row1 col5" >0.81</td>
#       <td id="T_03a43_row1_col6" class="data row1 col6" >0.66</td>
#       <td id="T_03a43_row1_col7" class="data row1 col7" >0.67</td>
#       <td id="T_03a43_row1_col8" class="data row1 col8" >2.97</td>
#     </tr>
#     <tr>
#       <th id="T_03a43_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_03a43_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_03a43_row2_col1" class="data row2 col1" >0.84</td>
#       <td id="T_03a43_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_03a43_row2_col3" class="data row2 col3" >0.80</td>
#       <td id="T_03a43_row2_col4" class="data row2 col4" >0.85</td>
#       <td id="T_03a43_row2_col5" class="data row2 col5" >0.82</td>
#       <td id="T_03a43_row2_col6" class="data row2 col6" >0.68</td>
#       <td id="T_03a43_row2_col7" class="data row2 col7" >0.69</td>
#       <td id="T_03a43_row2_col8" class="data row2 col8" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_03a43_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_03a43_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_03a43_row3_col1" class="data row3 col1" >0.84</td>
#       <td id="T_03a43_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_03a43_row3_col3" class="data row3 col3" >0.79</td>
#       <td id="T_03a43_row3_col4" class="data row3 col4" >0.85</td>
#       <td id="T_03a43_row3_col5" class="data row3 col5" >0.81</td>
#       <td id="T_03a43_row3_col6" class="data row3 col6" >0.67</td>
#       <td id="T_03a43_row3_col7" class="data row3 col7" >0.68</td>
#       <td id="T_03a43_row3_col8" class="data row3 col8" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_03a43_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_03a43_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_03a43_row4_col1" class="data row4 col1" >0.83</td>
#       <td id="T_03a43_row4_col2" class="data row4 col2" >0.00</td>
#       <td id="T_03a43_row4_col3" class="data row4 col3" >0.76</td>
#       <td id="T_03a43_row4_col4" class="data row4 col4" >0.84</td>
#       <td id="T_03a43_row4_col5" class="data row4 col5" >0.80</td>
#       <td id="T_03a43_row4_col6" class="data row4 col6" >0.65</td>
#       <td id="T_03a43_row4_col7" class="data row4 col7" >0.65</td>
#       <td id="T_03a43_row4_col8" class="data row4 col8" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_03a43_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_03a43_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_03a43_row5_col1" class="data row5 col1" >0.82</td>
#       <td id="T_03a43_row5_col2" class="data row5 col2" >0.00</td>
#       <td id="T_03a43_row5_col3" class="data row5 col3" >0.78</td>
#       <td id="T_03a43_row5_col4" class="data row5 col4" >0.83</td>
#       <td id="T_03a43_row5_col5" class="data row5 col5" >0.79</td>
#       <td id="T_03a43_row5_col6" class="data row5 col6" >0.63</td>
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Akhiri MLflow run
mlflow.end_run()
