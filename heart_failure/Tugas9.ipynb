# %%
import pandas as pd
from pycaret.datasets import get_data
from pycaret.classification import *

# %%
# Memuat data dari lokasi file
data = pd.read_csv('C:/Users/USER/Semester 4_MLOps/heart_failure/heart_failure_clinical_records_dataset.csv')
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
# Setup klasifikasi
s = setup(data, target='DEATH_EVENT', session_id=123)

# Membuat model klasifikasi
best = compare_models()

# Melakukan tuning pada model terbaik
tuned_model = tune_model(best)

# Menampilkan evaluasi model
evaluate_model(tuned_model)

# Menyelesaikan model
final_model = finalize_model(tuned_model)

# Menyimpan model ke file .pkl
save_model(final_model, 'heart_failure_classification_model')
# Out:
# <style type="text/css">
# #T_b543c_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b543c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b543c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b543c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b543c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b543c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b543c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b543c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b543c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b543c_row1_col1" class="data row1 col1" >DEATH_EVENT</td>
#     </tr>
#     <tr>
#       <th id="T_b543c_level0_row2" class="row_heading level0 row2" >2</th>
# ...
